# %% [markdown]
# # Glass Identification

# %% [markdown]
# ### Project Description
# The dataset describes the chemical properties of glass and involves classifying samples of glass using their chemical properties as one of six classes. The dataset was credited to Vina Spiehler in 1987. The study of classification of types of glass was motivated by criminological investigation. At the scene of the crime, the glass left can be used as evidence...if it is correctly identified!
#
# The chemical compositions are measured as the weight percent in corresponding oxide.
#
# #### Attribute Information-
#
# 1.	 Id number: 1 to 214
# 2.	 RI: refractive index
# 3.	Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
# 4.	Mg: Magnesium
# 5.	Al: Aluminum
# 6.	Si: Silicon
# 7.	K: Potassium
# 8.	Ca: Calcium
# 9.	Ba: Barium
# 10.	Fe: Iron
# 11.	Type of glass: (class attribute)
#
# •	1- building_windows_float_processed
# •	2- building_windows_non_float_processed
# •	3- vehicle_windows_float_processed
# •	4- vehicle_windows_non_float_processed (none in this database)
# •	5- containers
# •	6- tableware
# •	7- headlamps
#
# There are 214 observations in the dataset. The dataset can be divided into window glass (classes 1-4) and non-window glass (classes 5-7).
#
# Predict : Type of glass
#
# #### Dataset Link-
# •	https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv
# •	https://github.com/dsrscientist/dataset3

# %%
# importing required labraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# reading data
df = pd.read_csv("glass.csv")

# %%
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %% [markdown]
# Here we can see that the columns name are missing in our dataset. Lets first add columns name using attribute information which is mention in project description.

# %%
# list of columns name
columns = ['Id no.','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type of glass']

# %%
# adding columns name
df = pd.read_csv("glass.csv", names=columns)

# %%
# Our dataset after adding columns name
df
# Out:
#      Id no.       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0         1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1         2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2         3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3         4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4         5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..      ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209     210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210     211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211     212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212     213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213     214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type of glass
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ...

# %% [markdown]
# Our dataset has 214 rows and 11 columns in which ten columns are features and one is target variable. Type of glass is the target variable and other columns are features.

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
# checkig dimension of the dataset
df.shape
print('Total number of rows-',df.shape[0],'\nTotal number of columns-',df.shape[1])
# Out:
# Total number of rows- 214
# Total number of columns- 11

# %%
# checking the types of the columns
df.dtypes
# Out:
# Id no.             int64
# RI               float64
# Na               float64
# Mg               float64
# Al               float64
# Si               float64
# K                float64
# Ca               float64
# Ba               float64
# Fe               float64
# Type of glass      int64
# dtype: object

# %% [markdown]
# Columns contain two types of data int64 and float64. Id no. and Type of glass data types are int64. RI,Na,Mg,Al,Si,K,Ca,Ba and Fe data types are float64.

# %%
# checking null values
print("Null values in columns -")
print(df.isnull().sum())
print("\nTotal null values in dataset - ",df.isnull().sum().sum())
# Out:
# Null values in columns -
# Id no.           0
# RI               0
# Na               0
# Mg               0
# Al               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type of glass    0
# dtype: int64
#
# Total null values in dataset -  0

# %% [markdown]
# No null values present in dataset.

# %%
# lets check the duplicate rows in dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate values present.

# %%
# creating function for checking columns unique values
def value_count(dataframe):
    for i in dataframe.columns:
        print('number of unique value in',i,'column -',df[i].nunique())
        print(dataframe[i].value_counts())
        print('\n')

# %%
value_count(df)
# Out:
# number of unique value in Id no. column - 214
# 1      1
# 135    1
# 137    1
# 138    1
# 139    1
#       ..
# 75     1
# 76     1
# 77     1
# 78     1
# 214    1
# Name: Id no., Length: 214, dtype: int64
#
#
# number of unique value in RI column - 178
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51754    2
# 1.51841    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: RI, Length: 178, dtype: int64
#
#
# number of unique value in Na column - 142
# 13.02    5
# 13.21    5
# 13.00    5
# 13.64    4
# 13.33    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Na, Length: 142, dtype: int64
#
#
# number of unique value in Mg column - 94
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 2.76     1
# 3.15     1
# 2.90     1
# 3.83     1
# 1.78     1
# Name: Mg, Length: 94, dtype: int64
#
#
# number of unique value in Al column - 118
# 1.54    8
# 1.19    6
# ...

# %% [markdown]
# Here we can see the each column unique values

# %%
# dropping the column Id no.
df.drop(columns=['Id no.'],inplace=True)

# %%
# dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RI             214 non-null    float64
#  1   Na             214 non-null    float64
#  2   Mg             214 non-null    float64
#  3   Al             214 non-null    float64
#  4   Si             214 non-null    float64
#  5   K              214 non-null    float64
#  6   Ca             214 non-null    float64
#  7   Ba             214 non-null    float64
#  8   Fe             214 non-null    float64
#  9   Type of glass  214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# After removing column Id no. now we have total ten columns. No null values present.

# %%
# statistical description
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Type of glass
# count  214.000000  214.000000  214.000000     214.000000
# mean     8.956963    0.175047    0.057009       2.780374
# std      1.423153    0.497219    0.097439       2.103739
# ...

# %% [markdown]
# 1) count is same for all columns means no null values present.
# 2) Type of glass is the target varible.
# 3) checking mean,min,50% and max, some columns are right skewed and some are left skewed.
# 4) Right skewed distributed columns are RI,Na,Al,K,Ca,Ba ans Fe.
# 5) Left skewed distributed columns are Mg nad Si.

# %% [markdown]
# ### Data visualization

# %%
def plot(name):
    plt.figure(figsize = (20,16), facecolor = 'white')
    plotnumber = 1

    for i in name:
        if plotnumber <= 20:
            ax = plt.subplot(4 , 4 , plotnumber)
            plot_name(name[i],color='blue')
            plt.xlabel(i, fontsize = 12)
            plotnumber +=1
    plt.show()

# %%
# histogram plot
plot_name = sns.histplot
plot(df)

# %%
# scatter plot
sns.scatterplot(x='Na',y='Ca',data=df, color='red')
plt.show()

# %%
# scatter plot
sns.scatterplot(x='Na',y='RI',data=df, color='red')
plt.show()

# %%
# scatter plot
sns.scatterplot(x='RI',y='Type of glass',data=df, color='green')
plt.show()

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x='RI',y='Ca',data=df, color='red')
plt.show()

# %% [markdown]
# Ca and RI have positive relationship.

# %%
# distribution plot
plot_name = sns.distplot
plot(df)

# %%
# box plot
plot_name = sns.boxplot
plot(df)

# %%
# creating list of columns which contain outliers
out_col = ['RI','Na','Al','Si','K','Ca','Ba','Fe']

# %% [markdown]
# Lets check which method loses less data after removing outliers.

# %%
# copy dataset
df1=df.copy()
df2=df.copy()

# %%
# first method
total_outliers = []
for i in out_col:
    q1 = df1[i].quantile(0.25)
    q3 = df1[i].quantile(0.75)
    iqr = q3-q1

    high = (q3 + (1.5*iqr))
    low = (q3 - (1.5*iqr))
   
    outliers_high = np.where(df1[i]> high)
    outliers_low = np.where(df1[i]< low)
    print('\nOutliers indices in',i)
    
    print(outliers_high)
    print(outliers_low)
    
    outliers = len(outliers_high[0])+len(outliers_low[0])
    
    print('\nOutliers in',i,'=',outliers,'\n') 
    print('---------------------------------------------------------------')
    
    for i in outliers_high[0]:
        total_outliers.append(i)
    for j in outliers_low[0]:
        total_outliers.append(j)
        
total_outliers.sort()

total_outliers = set(total_outliers)

print('\nTotal outliers in dataset=',len(total_outliers))
print('\nData loss will be',(len(total_outliers)/df.shape[0])*100,'%')
# Out:
# Outliers indices in RI
# (array([ 47,  50, 103, 104, 105, 106, 107, 110, 111, 112, 131, 170, 187,
#        189], dtype=int64),)
# (array([ 56,  84, 163, 171, 172, 180, 184, 185, 200, 202], dtype=int64),)
#
# Outliers in RI = 24
#
# ---------------------------------------------------------------
#
# Outliers indices in Na
# (array([184, 189], dtype=int64),)
# (array([ 97, 101, 105, 106, 107, 110, 111, 149, 165, 166, 201], dtype=int64),)
#
# Outliers in Na = 13
#
# ---------------------------------------------------------------
#
# Outliers indices in Al
# (array([163, 171, 172, 191, 192, 195, 196, 197, 198, 199, 202, 208, 209],
#       dtype=int64),)
# (array([ 17,  21,  38,  39,  43,  47,  48,  50,  62,  63,  64,  66,  67,
#         68,  69, 102, 103, 109, 110, 111, 112, 151, 152, 157, 161, 162,
#        183, 184], dtype=int64),)
#
# Outliers in Al = 41
#
# ---------------------------------------------------------------
#
# Outliers indices in Si
# ...

# %%
# second method
x2 = df2.drop(columns = ['Type of glass'])
y2 = df2['Type of glass']

# z-score
from scipy.stats import zscore
z = np.abs(zscore(df[out_col]))

threshold = 3
outliers1 = np.where(z>3)
print('Outliers',outliers1)

out = set(outliers1[0])
print('\nTotal outliers =',len(out))

print('\nData loss will be',(len(out)/df.shape[0])*100,'%')
# Out:
# Outliers (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#        131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#        188, 189, 201, 201, 203, 207, 213], dtype=int64), array([5, 0, 1, 3, 5, 6, 0, 3, 5, 5, 5, 0, 5, 5, 7, 7, 2, 3, 6, 2, 4, 2,
#        4, 7, 1, 3, 3, 6, 3, 4, 6, 6, 6], dtype=int64))
#
# Total outliers = 20
#
# Data loss will be 9.345794392523365 %

# %% [markdown]
# Since data loss is high in both methods, I will continue with outliers

# %%
# checking skewness
df.skew()
# Out:
# RI               1.625431
# Na               0.454181
# Mg              -1.152559
# Al               0.907290
# Si              -0.730447
# K                6.551648
# Ca               2.047054
# Ba               3.416425
# Fe               1.754327
# Type of glass    1.114915
# dtype: float64

# %%
skewed_col = ['RI','Mg','Al','Si','K','Ca','Ba','Fe']
# reducing skewness
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
df[skewed_col] = pt.fit_transform(df[skewed_col])

# %%
# using standardscaler for rest columns
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Na']] = scaler.fit_transform(df[['Na']])

# %%
df
# Out:
#                RI        Na        Mg        Al        Si         K        Ca  \
# 0    7.285839e-17  0.284953  1.876273 -0.662630 -1.138642 -1.289781 -0.010654
# 1   -2.081668e-17  0.591817  0.668163 -0.077498  0.044314  0.274843 -0.884532
# 2   -5.898060e-17  0.149933  0.608046  0.291075  0.400267  0.018565 -0.938251
# 3   -1.734723e-17 -0.242853  0.778426 -0.228458 -0.115117  0.501963 -0.488967
# 4   -2.428613e-17 -0.169205  0.692438 -0.339129  0.526911  0.453753 -0.636365
# ..            ...       ...       ...       ...       ...       ...       ...
# 209 -5.551115e-17  0.898681 -1.739289  2.417218 -0.115117 -1.187926  0.334634
# 210 -4.163336e-17  1.856097 -1.739289  1.109283  0.498613 -1.619585 -0.319385
# 211  6.591949e-17  1.168721 -1.739289  1.159377  1.021794 -1.619585 -0.282733
# 212 -4.857226e-17  1.193270 -1.739289  1.024669  1.310019 -1.619585 -0.246446
# 213 -3.469447e-17  1.009152 -1.739289  1.258093  0.932538 -1.619585 -0.122236
#
# ...

# %%
# checking correlation
df.corr()
# Out:
#                      RI        Na        Mg        Al        Si         K  \
# RI             1.000000 -0.187036 -0.104402 -0.424647 -0.527953 -0.312758
# Na            -0.187036  1.000000 -0.256284  0.097072 -0.050310 -0.520799
# Mg            -0.104402 -0.256284  1.000000 -0.449470 -0.211779  0.350379
# Al            -0.424647  0.097072 -0.449470  1.000000  0.029822  0.198041
# Si            -0.527953 -0.050310 -0.211779  0.029822  1.000000 -0.077343
# K             -0.312758 -0.520799  0.350379  0.198041 -0.077343  1.000000
# Ca             0.758458 -0.240157 -0.354202 -0.311750 -0.138419 -0.463581
# Ba            -0.128535  0.435520 -0.541242  0.534876  0.053791 -0.311484
# Fe             0.128837 -0.191887  0.100592 -0.070475 -0.082235  0.071316
# Type of glass -0.166079  0.502898 -0.753515  0.555940  0.186630 -0.331584
#
#                      Ca        Ba        Fe  Type of glass
# RI             0.758458 -0.128535  0.128837      -0.166079
# ...

# %%
# heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,fmt=".2f")
plt.show()

# %% [markdown]
# 1) RI ans Ca have strong positive correlation.
# 2) Mg and Type of glass have strong negative correlation.
# 3) Ba and Type of glass have positive correlation.
# 4) Ba and Mg have negative correlation.

# %%
# separating target variable and features
x = df.drop(columns = ['Type of glass'])
y = df['Type of glass']

# %%
# checking variance inflation factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features']=x.columns
vif['vif values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif
# Out:
#   Features  vif values
# 0       RI    6.284335
# 1       Na    3.494099
# 2       Mg    4.084471
# 3       Al    2.424118
# 4       Si    1.650840
# 5        K    4.117091
# 6       Ca    5.634475
# 7       Ba    2.620252
# 8       Fe    1.092006

# %%
y.value_counts()
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of glass, dtype: int64

# %%
# replacing types value
y[(y<5)]=0            # 0 for window glass
y[(y>4)]=1            # 1 for non-window glass

# checking value count and dimension
print(y.value_counts())
print(y.shape)
# Out:
# 0    163
# 1     51
# Name: Type of glass, dtype: int64
# (214,)

# %%
# balancing data
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x,y = SM.fit_resample(x,y)

# %%
x.shape
# Out:
# (326, 9)

# %%
y.shape
# Out:
# (326,)

# %%
# importing required libraries
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report,roc_curve,confusion_matrix,auc,roc_auc_score
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,ExtraTreesClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# creating lists of models
LR = LogisticRegression()
RFC = RandomForestClassifier()
ABC = AdaBoostClassifier()
DTC = DecisionTreeClassifier()
GBC = GradientBoostingClassifier()
KNN = KNeighborsClassifier()
ETC = ExtraTreesClassifier()
svc = SVC()

model_list= [LR,RFC,ABC,DTC,GBC,KNN,ETC,svc]

# %%
# finding best random state
def random_state(model):
    max_acc = 0
    max_rs = 0
    for i in range(1,200):
        x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30, random_state=i)
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        acc = accuracy_score(y_test,y_pred)
        if acc>max_acc:
            max_acc=acc
            max_rs = i
    print('maximum accuracy=',max_acc,'\nbest random state=',max_rs)

# %%
# best random state for RandomForestClassifier
random_state(RFC)
# Out:
# maximum accuracy= 1.0
# best random state= 8

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30, random_state=8)

# %%
# function for model
def model(name):
    name.fit(x_train,y_train)
    y_pred=name.predict(x_test)
    acc_score = accuracy_score(y_test,y_pred)
    CM = confusion_matrix(y_test,y_pred)
    CR = classification_report(y_test,y_pred)
    print('Accuracy score =',acc_score,'\n\nconfusion matrix:-\n',CM,'\n\nclassification report:-\n',CR)
    
    print('checking Cross validation score:-\n')
    score_cv = cross_val_score(name,x,y)
    cv_mean = score_cv.mean()
    diff = (acc_score - cv_mean)
    print('cross validation scores:-',score_cv,'\ncross validation mean score =',cv_mean,
          '\nDifference between accuracy score and cross validation mean score =',diff)

# %%
# all models
for i in model_list:
    print('\n_____________ Using',i,'_____________\n')
    model(i)
# Out:
# _____________ Using LogisticRegression() _____________
#
# Accuracy score = 0.9897959183673469
#
# confusion matrix:-
#  [[49  0]
#  [ 1 48]]
#
# classification report:-
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99        49
#            1       1.00      0.98      0.99        49
#
#     accuracy                           0.99        98
#    macro avg       0.99      0.99      0.99        98
# weighted avg       0.99      0.99      0.99        98
#
# checking Cross validation score:-
#
# cross validation scores:- [0.90909091 1.         0.98461538 0.83076923 1.        ]
# cross validation mean score = 0.9448951048951049
# Difference between accuracy score and cross validation mean score = 0.04490081347224206
#
# _____________ Using RandomForestClassifier() _____________
#
# Accuracy score = 0.9897959183673469
#
# confusion matrix:-
#  [[48  1]
#  [ 0 49]]
#
# classification report:-
# ...

# %% [markdown]
# Our best model is KNeighborsClassifier. It has least difference between accuracy score and cross validation mean score.

# %% [markdown]
# #### Hyperparameter tuning

# %%
# parameters for KNN models
param = {'n_neighbors':[3,5,10,13,16],
         'algorithm':['auto','ball_tree','kd_tree','brute'],
         'leaf_size':[30,40,50],
         'n_jobs':[-2,-1,1]
          }

GSCV= GridSearchCV(estimator=KNN,param_grid=param,cv=5)
GSCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'leaf_size': [30, 40, 50], 'n_jobs': [-2, -1, 1],
#                          'n_neighbors': [3, 5, 10, 13, 16]})

# %%
# finding best parameter value
GSCV.best_params_
# Out:
# {'algorithm': 'auto', 'leaf_size': 30, 'n_jobs': -2, 'n_neighbors': 3}

# %%
Model = KNeighborsClassifier(n_neighbors=3,algorithm='auto',leaf_size=30,n_jobs=-2)

# %%
# final model
Model.fit(x_train,y_train)
y_pred=Model.predict(x_test)
acc_score = accuracy_score(y_test,y_pred)
CM = confusion_matrix(y_test,y_pred)
CR = classification_report(y_test,y_pred)
print('Accuracy score =',acc_score,'\n\nconfusion matrix:-\n',CM,'\n\nclassification report:-\n',CR)
# Out:
# Accuracy score = 0.9693877551020408
#
# confusion matrix:-
#  [[47  2]
#  [ 1 48]]
#
# classification report:-
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        49
#            1       0.96      0.98      0.97        49
#
#     accuracy                           0.97        98
#    macro avg       0.97      0.97      0.97        98
# weighted avg       0.97      0.97      0.97        98

# %%
# ROC curve
fpr,tpr,threshold =roc_curve(y_test,y_pred)
print('Threshold=',threshold,'\nFalse positive rate=',fpr,'\nTrue positive rate=',tpr)
# Out:
# Threshold= [2 1 0]
# False positive rate= [0.         0.04081633 1.        ]
# True positive rate= [0.         0.97959184 1.        ]

# %%
# plotting roc curve
plt.plot(fpr,tpr,color='red', label ='ROC')
plt.plot([0,1],[0,1], color = 'blue',linestyle='--')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
# AUC score
auc_score =roc_auc_score(y_test,y_pred)
print(auc_score)
# Out:
# 0.9693877551020408

# %%
# saving model
import pickle
pickle.dump(Model,open('Glass_identification.pkl','wb'))
